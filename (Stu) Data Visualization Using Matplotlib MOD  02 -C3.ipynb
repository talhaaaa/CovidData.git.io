# %%
import pandas as pd

# %%
df = pd.read_csv("WHO.csv")
df
# Out:
#       Date_reported                           Country  New_cases  \
# 0        2020-01-04                             China          1
# 1        2020-01-05                             China          0
# 2        2020-01-06                             China          3
# 3        2020-01-07                             China          0
# 4        2020-01-08                             China          0
# ...             ...                               ...        ...
# 31871    2020-07-31                            Panama       1046
# 31872    2020-07-31                       Timor-Leste          0
# 31873    2020-07-31                         Guatemala       1221
# 31874    2020-07-31  Saint Vincent and the Grenadines          0
# 31875    2020-07-31  Democratic Republic of the Congo         79
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 0                     1           0                  0
# 1                     1           0                  0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31876 entries, 0 to 31875
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date_reported      31876 non-null  object
#  1   Country            31876 non-null  object
#  2   New_cases          31876 non-null  int64
#  3   Cumulative_cases   31876 non-null  int64
#  4   New_deaths         31876 non-null  int64
#  5   Cumulative_deaths  31876 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 1.5+ MB

# %% [markdown]
# ## COVID-19 Dataset Description
#
# The dataset spans from January 4 to July 31 and contains daily COVID-19 reports for various countries. Initially, only data from China is present due to the virus being limited to China during that period.
#
# Each row in the dataset provides the following information:
#
# - **Date_reported**: The date when the data was reported in year-month-day format.
# - **Country**: The country to which the report corresponds.
# - **New_cases**: The number of new cases reported for that date and country.
# - **Cumulative_cases**: The total number of cases up to that date in that country.
# - **New_deaths**: The number of new deaths reported for that date and country.
# - **Cumulative_deaths**: The total number of deaths up to that date in that country.
#
# The dataset is organized in chronological order, beginning from January 4 and extending to July 31. This sequence of data points, ordered by time, is referred to as a time series.

# %%
df["Date_reported"]=pd.to_datetime(df['Date_reported'],format = "%Y-%m-%d")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31876 entries, 0 to 31875
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date_reported      31876 non-null  datetime64[ns]
#  1   Country            31876 non-null  object
#  2   New_cases          31876 non-null  int64
#  3   Cumulative_cases   31876 non-null  int64
#  4   New_deaths         31876 non-null  int64
#  5   Cumulative_deaths  31876 non-null  int64
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 1.5+ MB

# %% [markdown]
# # Italy

# %%
import matplotlib.pyplot as plt
Italy=df["Country"] == "Italy"
Italy_df=df[Italy]
Italy_df
# Out:
#       Date_reported Country  New_cases  Cumulative_cases  New_deaths  \
# 123      2020-01-29   Italy          6                 6           0
# 144      2020-01-30   Italy          0                 6           0
# 158      2020-01-31   Italy          0                 6           0
# 187      2020-02-01   Italy          0                 6           0
# 215      2020-02-02   Italy          0                 6           0
# ...             ...     ...        ...               ...         ...
# 30870    2020-07-27   Italy        254            246118           5
# 31097    2020-07-28   Italy        168            246286           5
# 31333    2020-07-29   Italy        202            246488          11
# 31629    2020-07-30   Italy        288            246776           6
# 31686    2020-07-31   Italy        382            247158           3
#
#        Cumulative_deaths
# 123                    0
# 144                    0
# 158                    0
# 187                    0
# ...

# %% [markdown]
# ## Graph
#
# **Note:** When dealing with time series data, line graphs are the most commonly used visualization.
#
# In a time series line graph:
# - The x-axis represents the independent time values.
# - The y-axis represents the dependent variable being observed.

# %%
plt.plot (Italy_df["Date_reported"],Italy_df['Cumulative_cases']) #x-axis , y-axis
# heading
plt.title("Italy :Cumulative Cases ")

# x label

plt.xlabel("Date")

# y label

plt.ylabel("Number of cases")

# to hide hex codes

plt.show()

# interference

print("Generaally a quantity which increase very quickly in\ the begining and then show down is called logarithmic graph")
# Out:
# Generaally a quantity which increase very quickly in\ the begining and then show down is called logarithmic grapg

# %% [markdown]
# # India

# %%
def plot_reported_cases(country_name):
    
    country_df = df[df['Country'] == country_name]


    plt.plot (country_df["Date_reported"],country_df['Cumulative_cases']) #x-axis , y-axis
    # heading
    plt.title(country_name+ "Cumulative Cases ")

    # x label

    plt.xlabel("Date")

    # y label

    plt.ylabel("Number of cases")

    # to hide hex codes

    plt.show()

plot_reported_cases("India")
# interference

print("Generaally a quantity that has slow start but \ go hight afterwards is called exponential graph")
# Out:
# Generaally a quantity that has slow start but \ go hight afterwards is called exponential graph

# %% [markdown]
# # Poland

# %%
plot_reported_cases("Poland")

# %% [markdown]
# # Plotting Multiple Countries

# %%
#plotting 1st 10 unique countries
len(df['Country'].unique())
Countries = df["Country"].unique()
Countries[:10]
# Out:
# array(['China', 'Thailand', 'Japan', 'Republic of Korea',
#        'United States of America', 'Singapore', 'Nepal', 'France',
#        'Viet Nam', 'Malaysia'], dtype=object)

# %%
for i in Countries[:10]:
    #print(i)
    plot_reported_cases(i)

# %% [markdown]
# # Multiple Plots

# %%
pakistan = df[df["Country"]=="Pakistan"]
uk =df[df["Country"]=="The United Kingdom"]
france =df[df["Country"]=="France"]

# %%
plt.plot(france["Date_reported"],france["Cumulative_deaths"])
plt.show()

plt.plot(uk["Date_reported"],uk["Cumulative_deaths"])
plt.show()

plt.plot(pakistan["Date_reported"],pakistan["Cumulative_deaths"])
plt.show()

# %%
plt.plot(france["Date_reported"],france["Cumulative_deaths"],\
        label = "France" , color = "blue")


plt.plot(uk["Date_reported"],uk["Cumulative_deaths"],\
        label="UK" , color = "Red")


plt.plot(pakistan["Date_reported"],pakistan["Cumulative_deaths"],\
        label = "Pakistan" , color = "Green")
plt.legend()
plt.show()

# %%
# Frequency of Countries in 1st 100 records
df['Country']
df['Country'].head(100).value_counts()
df['Country'].head(100).value_counts().plot(kind = 'bar')
plt.show()
